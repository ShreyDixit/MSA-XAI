# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model import Generator, Discriminator, train_model
import numpy as np
import torch
from torchvision import datasets
from torchvision import transforms as T
import torchvision.utils as vutils
import seaborn as sns
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib
from msapy import msa
import pickle as pkl
import ipywidgets as widgets
from ipywidgets import interact, fixed
import msa_utils
import bct
from netneurotools import cluster

SEED = 42
RNG = np.random.default_rng(SEED)
matplotlib.rcParams['figure.figsize'] = (12, 6)
torch.manual_seed(SEED)

# %%
workers = 4
batch_size = 128
image_size = 128

nc = 3
nz = 100
ngf = 64
ndf = 64
num_layers = 6

lr = 0.0002
num_epochs = 30
num_permutations = 3000

dataroot = "data/celebA"
device = "cuda:0"
model_path = "saved_results/celebA_GAN_model.pth"
shapley_modes_path = "saved_results/shapley_modes_celebA.pkl"

# %%
dataset = datasets.CelebA(root=dataroot,
                        split='train',
                        transform=T.Compose([
                               T.Resize(image_size),
                               T.CenterCrop(image_size),
                               T.ToTensor(),
                           ]),
                        download=True)

dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=workers)
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:32], padding=2, normalize=False).cpu(),(1,2,0)))
# Out:
# Files already downloaded and verified

# %%
generator = Generator(nz, ngf, nc).to(device)
discriminator = Discriminator(nc, ndf, num_layers).to(device)

fixed_noise = torch.load('fixed_noise.t').to(device)

# %%
image_list = train_model(generator, discriminator, num_epochs, lr, dataloader, nz, fixed_noise, save_every=500, device=device)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
torch.save(generator.state_dict(), model_path)

# %%
generator.load_state_dict(torch.load(model_path))
generator.eval();

# %%
def display_images(images):
    """
    Display images with a slider.
    
    Parameters:
    - images: A list of numpy ndarrays representing the images.
    """
    
    def view_image(index):
        plt.imshow(images[index]) # Assuming the images are in grayscale
        plt.axis('off') # Hide axes
        plt.show()
    
    # Slider
    widgets.interact(view_image, index=widgets.IntSlider(min=0, max=len(images)-1, step=1, value=0))

# %%
generator.eval()
final_fake_images = generator(fixed_noise).cpu().detach()
final_fake_images = vutils.make_grid(final_fake_images, padding=2, normalize=True)
final_fake_images = final_fake_images.numpy().transpose(1, 2, 0)

plt.figure(figsize=(8,8))
plt.axis("off")
plt.imshow(final_fake_images)
plt.show()

# %%
elements = []
elements = [(0, i) for i in range(ngf * 16)]
elements += [(i, j) for i in range(1, 5) for j in range(ngf * 2 ** (4 - i))]
elements += [(5, i) for i in range(3)]
len(elements)
# Out:
# 1987

# %%
@torch.no_grad()
def objective_function(complements):
    lesion_dict = defaultdict(list)
    for x, y in complements:
        lesion_dict[x].append(y)
    return generator(fixed_noise, lesion_dict).detach().cpu().numpy()

# %%
shapley_modes = msa.interface(
    elements=elements,
    n_permutations=num_permutations, 
    objective_function=objective_function,
    rng=RNG)
# Out:
# /home/shrey/miniconda3/envs/msa-xai/lib/python3.11/site-packages/msapy/msa.py:68: UserWarning: Specified number of permutations is kinda small so the results might not be as accurate.
#   _check_valid_n_permutations(n_permutations)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00&lt;?]
#     </div>
#
#
#
#     <div>
#       <progress value='422' class='' max='1987' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.24% [422/1987 00:04&lt;00:14]
#     </div>

# %%
shapley_modes.to_pickle(shapley_modes_path)

# %%
with open(shapley_modes_path, 'rb') as fp:
    shapley_modes = pkl.load(fp)

# %%
plt.imshow(msa_utils.convert_to_image_grid(shapley_modes.get_total_contributions()))

# %%
layer = 5

ims = [msa_utils.convert_to_image_grid(layer_contrib) for layer_contrib in msa_utils.get_layer_contributions(layer, shapley_modes)]
display_images(ims)
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=2), Output()), _dom_classes=('widget-interac…

# %%
layer = 3

ims = [msa_utils.convert_to_image_grid(layer_contrib) for layer_contrib in msa_utils.get_layer_contributions(layer, shapley_modes)]
display_images(ims)
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=127), Output()), _dom_classes=('widget-inter…

# %%
# Out:
# /home/shrey/miniconda3/envs/msa-xai/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/shrey/miniconda3/envs/msa-xai/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
